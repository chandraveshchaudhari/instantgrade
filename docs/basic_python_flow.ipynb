# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./docs/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent     # go up to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from evaluator import Evaluator

# %%
eval = Evaluator("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/solution/python/sample_solutions.ipynb", "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python")
eval.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 eval = Evaluator("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/solution/python/sample_solutions.ipynb", "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python")
# ----> 2 eval.run()
#
# File /Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/evaluator.py:64, in Evaluator.run(self)
#      59 def run(self) -> Any:
#      60     """Run the full pipeline: load -> execute -> compare -> report.
#      61
#      62     Returns the generated report object from the reporting service.
#      63     """
# ---> 64     submissions = self.load()
#      65     executed = self.execute_all(submissions)
#      66     report = self.build_report(executed)
#
# File /Volumes/MacSSD/Areas/Github_Repositories/evaluator/src/evaluator/evaluator.py:72, in Evaluator.load(self)
#      70 def load(self) -> List[Path]:
#      71     """Load and return list of submission file paths using ingestion service."""
# ---> 72     return self.ingestion.IngestionService(self.solution_file_path, self.submission_folder_path)
#
# AttributeError: 'IngestionService' object has no attribute 'IngestionService'

# %% [markdown]
# # EOF
