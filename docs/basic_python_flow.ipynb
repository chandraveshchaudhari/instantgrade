# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./docs/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent     # go up to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from evaluator import Evaluator

# %%
eval = Evaluator("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/solution/python/sample_solutions.ipynb", "/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/submissions/python")
result = eval.run()
# Out:
# /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# /Volumes/MacSSD/Areas/Github_Repositories/evaluator/.venv/lib/python3.13/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)

# %%
result.to_html("/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/reports/python/report.html")
# Out:
# PosixPath('/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/reports/python/report.html')

# %%
result.dataframe()
# Out:
#                                                  file           student  \
# 0   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 1   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 2   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 3   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 4   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 5   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 6   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 7   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 8   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 9   /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 10  /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# 11  /Volumes/MacSSD/Areas/Github_Repositories/eval...  perfect but zero
# ...

# %%
from evaluator.utils.io_utils import generate_student_notebook


generate_student_notebook(
    instructor_path="/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/example1/control_flow_practice_questions.ipynb",
    output_path="/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/example1/control_flow_practice_questions_student_notebook.ipynb"
)
# Out:
# ✅ Student notebook generated at: /Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/example1/control_flow_practice_questions_student_notebook.ipynb

# %% [markdown]
# # EOF
