# %% [markdown]
# # What is Python?
#
# ## Introduction
# Python is a high-level programming language known for its simplicity and readability.
# It is widely used in education, business, data analysis, and web development.

# %% [markdown]
# ## Key Concepts
#
# - Python is an interpreted language
# - It uses simple and readable syntax
# - It supports multiple programming styles
# - It has a large standard library

# %%
x = 5
y = 10
x + y
# Out:
# 15

# %% [markdown]
# ## Real-Life or Business Use Case
#
# Python is widely used in business and economics for performing basic calculations
# such as profit estimation, cost analysis, and revenue tracking.
# Its simple syntax allows professionals to quickly compute and interpret results
# without complex programming knowledge.

# %%
price = 20
demand = 100 - price
demand
# Out:
# 80

# %% [markdown]
# ## Advantages
#
# - Easy to learn and use
# - Open-source and free
# - Large community support
# - Used across many industries

# %% [markdown]
# ## Limitations
#
# - Slower compared to some compiled languages
# - Not ideal for mobile app development
# - High memory usage in some cases

# %% [markdown]
# ## Summary
#
# Python is a versatile and beginner-friendly programming language.
# Its simplicity and wide range of applications make it one of the most popular
# languages today.
