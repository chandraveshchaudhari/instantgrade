# %% [markdown]
# # Object-Oriented Programming (OOP) – Study Notes
# Run each code cell to understand how OOP works in Python.

# %% [markdown]
# ## 1. Classes and Objects

# %% [markdown]
# A class is a blueprint for creating objects.

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(f"Name: {self.name}, Age: {self.age}")

# Creating objects
s1 = Student("Gunjan", 20)
s1.display()

# %% [markdown]
# ## 2. Why Object-Oriented Programming

# %% [markdown]
# ### Benefits of OOP
# - Code reusability
# - Better organization of large programs
# - Real-world modeling
# - Easier maintenance and debugging

# %% [markdown]
# ## 3. Code Cell Feature in Jupyter

# %% [markdown]
# In Jupyter Notebook, code is written in **cells**.
# - Each cell can be run independently.
# - Helps in step-by-step execution.

# %%
print("This is a code cell example.")

# %% [markdown]
# ## 4. Inheritance and Polymorphism

# %% [markdown]
# ### Inheritance

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def show(self):
        print("Name:", self.name)

class Employee(Person):
    def __init__(self, name, salary):
        super().__init__(name)
        self.salary = salary

    def show_salary(self):
        print("Salary:", self.salary)

emp = Employee("Riya", 50000)
emp.show()
emp.show_salary()

# %% [markdown]
# ### Polymorphism

# %%
class Dog:
    def speak(self):
        print("Dog barks")

class Cat:
    def speak(self):
        print("Cat meows")

for animal in (Dog(), Cat()):
    animal.speak()

# %% [markdown]
# ## 5. Static, Class, and Instance Methods

# %%
class Example:
    class_variable = "I am a class variable"

    def instance_method(self):
        return "This is an instance method"

    @classmethod
    def class_method(cls):
        return f"Accessing: {cls.class_variable}"

    @staticmethod
    def static_method():
        return "This is a static method"

obj = Example()
print(obj.instance_method())
print(Example.class_method())
print(Example.static_method())

# %% [markdown]
# ## 6. Decorators: Enhancing Functions and Methods

# %%
def my_decorator(func):
    def wrapper():
        print("Before function runs")
        func()
        print("After function runs")
    return wrapper

@my_decorator
def say_hello():
    print("Hello!")

say_hello()

# %% [markdown]
# ## 7. Interactions Between Classes

# %%
class Engine:
    def start(self):
        print("Engine started")

class Car:
    def __init__(self):
        self.engine = Engine()

    def drive(self):
        self.engine.start()
        print("Car is moving")

car = Car()
car.drive()

# %% [markdown]
# ## 8. Exercise: Building Classes for ML Pipeline

# %%
class DataLoader:
    def load(self):
        print("Loading data...")

class Model:
    def train(self):
        print("Training model...")

class Evaluator:
    def evaluate(self):
        print("Evaluating model...")

# Simulated pipeline
loader = DataLoader()
model = Model()
evaluator = Evaluator()

loader.load()
model.train()
evaluator.evaluate()

# %% [markdown]
# ## 9. OOP for Business Applications

# %% [markdown]
# ### Banking Example

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient funds")

    def show_balance(self):
        print("Balance:", self.balance)

acc = BankAccount("Gunjan", 1000)
acc.deposit(500)
acc.withdraw(200)
acc.show_balance()

# %% [markdown]
# ### HR Example

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def annual_salary(self):
        return self.salary * 12

emp = Employee("Riya", 40000)
print(emp.annual_salary())

# %% [markdown]
# ### Retail Example

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

class Cart:
    def __init__(self):
        self.items = []

    def add_product(self, product):
        self.items.append(product)

    def total_price(self):
        return sum(item.price for item in self.items)

p1 = Product("Shampoo", 200)
p2 = Product("Facewash", 150)

cart = Cart()
cart.add_product(p1)
cart.add_product(p2)

print("Total:", cart.total_price())
