# %% [markdown]
# # Intermediate Python Programming
# Structured Study Notes for VS Code (Jupyter Notebook)

# %% [markdown]
# ## 1. List Comprehensions and Generator Expressions
# ### List Comprehension
# Compact way to create lists.
# ```python
# squares = [x**2 for x in range(5)]
# ```
#
# ### With Condition
# ```python
# even_numbers = [x for x in range(10) if x % 2 == 0]
# ```
#
# ### Generator Expression
# Uses parentheses and is memory efficient.
# ```python
# gen = (x**2 for x in range(5))
# ```

# %%
# Example
squares = [x**2 for x in range(6)]
print(squares)

gen = (x**2 for x in range(6))
print(list(gen))

# %% [markdown]
# ## 2. File Input Output (CSV, Excel, JSON, XML)
# ### Text File
# ```python
# with open('sample.txt', 'w') as f:
#     f.write('Hello File Handling')
# ```
#
# ### CSV
# ```python
# import pandas as pd
# df = pd.read_csv('data.csv')
# ```
#
# ### Excel
# ```python
# df = pd.read_excel('data.xlsx')
# ```
#
# ### JSON
# ```python
# import json
# with open('data.json') as f:
#     data = json.load(f)
# ```

# %% [markdown]
# ## 3. Error Handling and Exceptions
# ```python
# try:
#     x = 10 / 0
# except ZeroDivisionError:
#     print('Cannot divide by zero')
# finally:
#     print('Execution Complete')
# ```

# %%
try:
    num = 5
    result = 100 / num
    print(result)
except ValueError:
    print('Invalid input!')
except ZeroDivisionError:
    print('Number cannot be zero!')

# %% [markdown]
# ## 4. Working with Libraries (NumPy, Pandas, Matplotlib)
# ### NumPy
# ```python
# import numpy as np
# arr = np.array([1, 2, 3])
# ```
#
# ### Pandas
# ```python
# import pandas as pd
# df = pd.DataFrame({'Sales':[100,200,300]})
# ```
#
# ### Matplotlib
# ```python
# import matplotlib.pyplot as plt
# plt.plot([1,2,3], [10,20,30])
# plt.show()
# ```

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = np.array([10, 20, 30, 40])
df = pd.DataFrame({'Revenue': data})
print(df.describe())

plt.plot(df['Revenue'])
plt.show()

# %% [markdown]
# ## 5. Business Data Formats (Excel, PDFs, APIs)
# - **Excel**: Financial reports and dashboards
# - **PDFs**: Invoices and official reports
# - **APIs**: Fetch live data from external services
#
# Example API call:
# ```python
# import requests
# response = requests.get('https://api.example.com/data')
# print(response.json())
# ```

# %% [markdown]
# ## Summary
# - Comprehensions improve efficiency
# - File handling manages business data
# - Exceptions make programs robust
# - Libraries simplify analytics
# - Business formats are essential in real-world applications
