# %% [markdown]
# # Resources and Next Steps
#
# This notebook provides learning resources and practice steps.

# %% [markdown]
# ## Learning Resources
# - Python Official Documentation: https://docs.python.org/3/
# - Pandas Documentation: https://pandas.pydata.org/docs/
# - Scikit-Learn Documentation: https://scikit-learn.org/
# - Kaggle: https://www.kaggle.com/

# %% [markdown]
# ## Practice Tasks
# 1. Automate file sorting by extension.
# 2. Load and analyze a real CSV dataset.
# 3. Build a simple prediction model.

# %%
# Simple Practice Task: Sorting Files by Extension
import os
import shutil

source_folder = "mixed_files"

for file in os.listdir(source_folder):
    ext = file.split(".")[-1]
    dest_folder = os.path.join(source_folder, ext)
    
    if not os.path.exists(dest_folder):
        os.makedirs(dest_folder)
        
    shutil.move(os.path.join(source_folder, file), os.path.join(dest_folder, file))

print("Files sorted successfully!")
