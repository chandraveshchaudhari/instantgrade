# %% [markdown]
# # Advanced Python Techniques
# Comprehensive Study Notes for VS Code (Jupyter Notebook)

# %% [markdown]
# ## 1. Functional Programming (map, filter, reduce)
# Functional programming focuses on using functions as arguments and avoiding state changes.
#
# ### map()
# ```python
# numbers = [1, 2, 3, 4]
# squared = list(map(lambda x: x**2, numbers))
# ```
#
# ### filter()
# ```python
# even = list(filter(lambda x: x % 2 == 0, numbers))
# ```
#
# ### reduce()
# ```python
# from functools import reduce
# total = reduce(lambda x, y: x + y, numbers)
# ```

# %%
from functools import reduce

numbers = [1, 2, 3, 4]

squared = list(map(lambda x: x**2, numbers))
even = list(filter(lambda x: x % 2 == 0, numbers))
total = reduce(lambda x, y: x + y, numbers)

print('Squared:', squared)
print('Even:', even)
print('Total:', total)

# %% [markdown]
# ## 2. Multithreading and Multiprocessing
# Used to improve performance for CPU-bound and I/O-bound tasks.
#
# ### Multithreading (I/O bound)
# ```python
# import threading
# ```
#
# ### Multiprocessing (CPU bound)
# ```python
# from multiprocessing import Process
# ```

# %% [markdown]
# ## 3. Working with APIs and Web Scraping
# ### API Example
# ```python
# import requests
# response = requests.get('https://api.example.com/data')
# data = response.json()
# ```
#
# ### Web Scraping Example
# ```python
# from bs4 import BeautifulSoup
# import requests
#
# page = requests.get('https://example.com')
# soup = BeautifulSoup(page.text, 'html.parser')
# print(soup.title.text)
# ```

# %% [markdown]
# ## 4. Data Visualization
# Visualization helps interpret business insights.
# - Line charts
# - Bar charts
# - Scatter plots
# - Heatmaps

# %% [markdown]
# ## 5. Matplotlib Plotting Basics
# ```python
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3]
# y = [10, 20, 30]
#
# plt.plot(x, y)
# plt.title('Sales Trend')
# plt.xlabel('Month')
# plt.ylabel('Revenue')
# plt.show()
# ```

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3]
y = [10, 20, 30]

plt.plot(x, y)
plt.title('Sales Trend')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ## 6. Seaborn for Advanced Visualizations
# Built on top of Matplotlib for statistical graphics.
#
# ```python
# import seaborn as sns
# import pandas as pd
#
# df = pd.DataFrame({'Sales':[100,200,150], 'Month':['Jan','Feb','Mar']})
# sns.barplot(x='Month', y='Sales', data=df)
# ```

# %% [markdown]
# ## 7. Interactive Plots with Plotly and Dashboards
# ```python
# import plotly.express as px
#
# df = px.data.iris()
# fig = px.scatter(df, x='sepal_width', y='sepal_length')
# fig.show()
# ```

# %% [markdown]
# ## 8. Automating Business Reports (Excel, PowerPoint, PDFs)
# - **Excel**: openpyxl, pandas
# - **PowerPoint**: python-pptx
# - **PDF**: reportlab
#
# Example (Excel export):
# ```python
# import pandas as pd
# df = pd.DataFrame({'Revenue':[1000,2000,3000]})
# df.to_excel('report.xlsx', index=False)
# ```

# %% [markdown]
# ## Summary
# - Functional programming simplifies data processing
# - Concurrency improves performance
# - APIs and scraping enable real-time data collection
# - Visualization communicates insights effectively
# - Automation increases business efficiency
