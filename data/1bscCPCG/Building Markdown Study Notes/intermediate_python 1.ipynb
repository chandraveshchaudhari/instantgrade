# %% [markdown]
# # Intermediate Python Programming
#
# This notebook covers intermediate Python concepts with examples.

# %% [markdown]
# ## 1. List Comprehensions and Generator Expressions

# %%
squares = [x**2 for x in range(10)]
squares

# %% [markdown]
# ## 2. File Input Output (CSV Excel JSON XML)

# %%
import csv
# Example placeholder

# %% [markdown]
# ## 3. Error Handling and Exceptions

# %%
try:
    x = int('a')
except ValueError as e:
    print(e)

# %% [markdown]
# ## 4. Working with Libraries (NumPy Pandas Matplotlib)

# %%
import numpy as np
np.array([1,2,3])

# %% [markdown]
# ## 5. Business Data Formats (Excel PDFs APIs)

# %%
# Placeholder for business formats examples
