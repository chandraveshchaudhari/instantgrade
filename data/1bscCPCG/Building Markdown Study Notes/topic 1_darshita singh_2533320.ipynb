# %% [markdown]
# # Introduction to Python for Machine Learning and Business

# %% [markdown]
# Python is one of the most widely used programming languages in business analytics,
# data science, and machine learning. Its simplicity and strong library support make it ideal.

# %% [markdown]
# ## Why Python for Business and Machine Learning

# %% [markdown]
# - Easy to learn and readable
# - Powerful libraries (NumPy, Pandas, Scikit-learn)
# - Used by top companies
# - Excellent for automation and analytics

# %% [markdown]
# ## Python Development Tools

# %% [markdown]
# • Jupyter Notebook
# • VS Code
# • PyCharm
# • Google Colab

# %% [markdown]
# ## Setting Up Your Python Environment

# %% [markdown]
# 1. Install Python
# 2. Install VS Code
# 3. Install Python & Jupyter extensions
# 4. Create a `.ipynb` file

# %%
import sys
sys.version

# %% [markdown]
# ## Writing Your First Python Program

# %%
print('Hello, World!')

# %%
company = 'Amazon'
revenue = 514000
print(company, revenue)

# %% [markdown]
# ## Business Use Cases of Python

# %% [markdown]
# - Data Analysis
# - Automation
# - Machine Learning
# - Visualization

# %%
sales = [12000, 15000, 17000, 16000, 18000]
print('Average Sales:', sum(sales)/len(sales))

# %% [markdown]
# ## Summary
# Python is a powerful tool for modern business and machine learning.
