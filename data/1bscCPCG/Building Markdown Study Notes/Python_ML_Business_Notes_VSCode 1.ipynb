# %% [markdown]
# # Introduction to Python for Machine Learning and Business
#
# Structured study notes for VS Code + Jupyter Notebook.

# %% [markdown]
# ## Why Python for Business and ML
# - Simple and beginner-friendly
# - Powerful data + ML libraries
# - Used in finance, marketing, analytics, AI
# - Great for automation

# %% [markdown]
# ## Python Development Tools
# - Jupyter Notebook (interactive)
# - VS Code (recommended)
# - PyCharm
# - Google Colab (cloud)

# %% [markdown]
# ## Setting Up Your Python Environment
# 1. Install Python
# 2. Install VS Code
# 3. Add Python + Jupyter extensions
# 4. Create virtual environment
# 5. Install libraries

# %%
# !pip install numpy pandas matplotlib scikit-learn

# %% [markdown]
# ## Your First Python Program

# %%
print("Hello, World!")
name = input("Enter your name: ")
print(f"Welcome, {name}!")

# %% [markdown]
# ## Business Use Cases
# ### Automation
# - Excel automation
# - Report generation
#
# ### Analytics
# - Sales & customer analysis
#
# ### Machine Learning
# - Forecasting
# - Fraud detection
# - Recommendations

# %%
import pandas as pd

data = {
    'Month': ['Jan', 'Feb', 'Mar'],
    'Revenue': [10000, 14000, 19000]
}

df = pd.DataFrame(data)
df

# %% [markdown]
# ## Key Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
#
# Master these for business + ML.
