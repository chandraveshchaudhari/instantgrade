# %% [markdown]
# # Advanced Python Techniques
#
# Advanced-level study notes for Business, Analytics, and Machine Learning using VS Code + Jupyter Notebook.

# %% [markdown]
# ## Functional Programming (Map, Filter, Reduce)
# Functional programming helps write clean and efficient code.

# %%
from functools import reduce

nums = [1, 2, 3, 4, 5]

squared = list(map(lambda x: x**2, nums))
evens = list(filter(lambda x: x % 2 == 0, nums))
sum_all = reduce(lambda a, b: a + b, nums)

squared, evens, sum_all

# %% [markdown]
# ## Multithreading and Multiprocessing
# Used to speed up programs and handle multiple tasks.

# %%
import threading

def print_numbers():
    for i in range(5):
        print(i)

thread = threading.Thread(target=print_numbers)
thread.start()

# %% [markdown]
# ## Working with APIs and Web Scraping
# Used to collect live data from the web.

# %%
import requests

url = "https://api.github.com"
response = requests.get(url)
response.status_code

# %% [markdown]
# ## Data Visualization Overview
# Visuals help in business decision making.

# %% [markdown]
# ## Matplotlib Plotting Basics

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.figure()
plt.plot(x, y)
plt.title("Basic Line Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ## Seaborn for Advanced Visualizations

# %%
import seaborn as sns
import pandas as pd

data = pd.DataFrame({
    'Category': ['A', 'A', 'B', 'B'],
    'Value': [10, 15, 20, 25]
})

sns.barplot(x='Category', y='Value', data=data)

# %% [markdown]
# ## Interactive Plots with Plotly
# Used for dashboards and interactive charts.

# %%
import plotly.express as px

df = px.data.iris()
fig = px.scatter(df, x='sepal_width', y='sepal_length', color='species')
fig.show()

# %% [markdown]
# ## Automating Business Reports
# Automate Excel, PowerPoint, and PDF reports.

# %%
import pandas as pd

sales = pd.DataFrame({
    'Month': ['Jan', 'Feb', 'Mar'],
    'Sales': [12000, 15000, 18000]
})

sales.to_excel('monthly_sales.xlsx', index=False)

sales

# %% [markdown]
# ## Key Takeaways
# - Functional programming improves code clarity
# - Concurrency improves performance
# - Visualization is critical for business
# - Automation saves time and reduces errors
