# %% [markdown]
# # OOP for Business Applications
# ---

# %% [markdown]
# ## Introduction
# OOP is widely used in business applications because it models real-world entities effectively.

# %% [markdown]
# ## Banking Example
# Banking systems use OOP to manage accounts, transactions, and customers.

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
    
    def withdraw(self, amount):
        if amount <= self.balance:
            self.balance -= amount
        else:
            print("Insufficient balance")

acc = BankAccount("John", 1000)
acc.deposit(500)
print(acc.balance)

# %% [markdown]
# ## HR Example
# HR systems use OOP to manage employee records and payroll.

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
    
    def display_salary(self):
        print(f"{self.name}'s Salary: {self.salary}")

# %% [markdown]
# ## Retail Example
# Retail systems use OOP to manage products, inventory, and sales.

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price
    
    def display_product(self):
        print(f"Product: {self.name}, Price: {self.price}")
