# %% [markdown]
# # Support Vector Machines (SVM)
#
# ## Learning Objectives
# - Max-margin intuition
# - Kernel SVMs
# - Soft margin & regularization
# - Sentiment classification lab

# %% [markdown]
# ## 1. Max-Margin Intuition
# SVM finds the hyperplane that maximizes the margin between classes.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVC

X = np.array([[2,2], [4,4], [4,0], [0,0]])
y = [0, 0, 1, 1]

model = SVC(kernel='linear')
model.fit(X, y)

plt.scatter(X[:,0], X[:,1], c=y)
plt.title('Linear SVM')
plt.show()

# %% [markdown]
# ## 2. Kernel SVMs
# Kernels allow non-linear classification.

# %%
from sklearn.datasets import make_circles

X, y = make_circles(noise=0.1, factor=0.2)

for kernel in ['linear','poly','rbf']:
    model = SVC(kernel=kernel)
    model.fit(X,y)
    plt.scatter(X[:,0], X[:,1], c=y)
    plt.title(kernel)
    plt.show()

# %% [markdown]
# ## 3. Soft Margin & Regularization
# Parameter C controls the tradeoff between margin size and misclassification.

# %%
for C in [0.1,1,100]:
    model = SVC(C=C, kernel='linear')
    model.fit(X,y)
    plt.scatter(X[:,0], X[:,1], c=y)
    plt.title(f'C={C}')
    plt.show()

# %% [markdown]
# ## 4. Lab – Sentiment Classification

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

texts = ['I love this product','Worst experience','Amazing service','I hate it']
labels = [1,0,1,0]

X = TfidfVectorizer().fit_transform(texts)
X_train, X_test, y_train, y_test = train_test_split(X, labels)

model = SVC(kernel='linear')
model.fit(X_train, y_train)

print('Accuracy:', accuracy_score(y_test, model.predict(X_test)))
