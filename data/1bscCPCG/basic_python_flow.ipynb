# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./data/python_example1/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent.parent     # go up two levels to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from instantgrade import Evaluator

# %% [markdown]
# from instantgrade.utils.io_utils import generate_student_notebook
#
# generate_student_notebook(
#     instructor_path="./control_flow_assessment.ipynb",
#     output_path="./submissions/student_notebook.ipynb"
# )

# %%
from instantgrade import Evaluator

# Use the corrected instructor solution file WITH tests
solution_file = NOTEBOOK_DIR / "sample_solution_with_tests.ipynb"
submission_folder = NOTEBOOK_DIR / "Mid-Semester Exam for Batch 3"

# Test with LOCAL execution first to see detailed output
eval = Evaluator(
    solution_file_path=str(solution_file),
    submission_folder_path=str(submission_folder),
    use_docker=False,      # Use local execution for debugging
    log_path=str(NOTEBOOK_DIR / "logs"),
    log_level="DEBUG",
)

report = eval.run()
eval.to_html(str(NOTEBOOK_DIR / "reports" / "evaluation_report_with_tests.html"))
# Out:
# Starting evaluation pipeline...
# Loading instructor solution...
# Loading instructor solution...
# Loaded 16 questions.
# Discovered 51 submissions to grade.
# Starting Local evaluation pipeline...
# [1/51] Grading: ANAY 2423357.ipynb
# [Local] Grading ANAY 2423357.ipynb
# Loaded 16 questions.
# Discovered 51 submissions to grade.
# Starting Local evaluation pipeline...
# [1/51] Grading: ANAY 2423357.ipynb
# [Local] Grading ANAY 2423357.ipynb
# [2/51] Grading: Aakarsh_Jawa_2423380.ipynb
# [Local] Grading Aakarsh_Jawa_2423380.ipynb
# [2/51] Grading: Aakarsh_Jawa_2423380.ipynb
# [Local] Grading Aakarsh_Jawa_2423380.ipynb
# [3/51] Grading: Aradhya_Mishra_2423371.ipynb
# [Local] Grading Aradhya_Mishra_2423371.ipynb
# [3/51] Grading: Aradhya_Mishra_2423371.ipynb
# [Local] Grading Aradhya_Mishra_2423371.ipynb
# [4/51] Grading: ArunMG(2423360).ipynb
# [Local] Grading ArunMG(2423360).ipynb
# [4/51] Grading: ArunMG(2423360).ipynb
# [Local] Grading ArunMG(2423360).ipynb
# [5/51] Grading: Devansh_Grover_2423366.ipynb
# [Local] Grading Devansh_Grover_2423366.ipynb
# [5/51] Grading: Devansh_Grover_2423366.ipynb
# [Local] Grading Devansh_Grover_2423366.ipynb
# [6/51] Grading: Divitvats.2423355.1.ipynb
# [Local] Grading Divitvats.2423355.1.ipynb
# [6/51] Grading: Divitvats.2423355.1.ipynb
# [Local] Grading Divitvats.2423355.1.ipynb
# [7/51] Grading: Divitvats.2423355.2.ipynb
# [Local] Grading Divitvats.2423355.2.ipynb
# [7/51] Grading: Divitvats.2423355.2.ipynb
# [Local] Grading Divitvats.2423355.2.ipynb
# [8/51] Grading: Divitvats.2423355.ipynb
# [Local] Grading Divitvats.2423355.ipynb
# [8/51] Grading: Divitvats.2423355.ipynb
# [Local] Grading Divitvats.2423355.ipynb
# [9/51] Grading: Johann_Karl 2423382 (2) (1).ipynb
# [Local] Grading Johann_Karl 2423382 (2) (1).ipynb
# [9/51] Grading: Johann_Karl 2423382 (2) (1).ipynb
# [Local] Grading Johann_Karl 2423382 (2) (1).ipynb
# [10/51] Grading: Johann_Karl 2423382 mid sem.ipynb
# [Local] Grading Johann_Karl 2423382 mid sem.ipynb
# [10/51] Grading: Johann_Karl 2423382 mid sem.ipynb
# [Local] Grading Johann_Karl 2423382 mid sem.ipynb
# [11/51] Grading: Johann_Karl 2423382.ipynb
# [Local] Grading Johann_Karl 2423382.ipynb
# [11/51] Grading: Johann_Karl 2423382.ipynb
# [Local] Grading Johann_Karl 2423382.ipynb
# [12/51] Grading: Kanishka Singh_2423376.ipynb
# [Local] Grading Kanishka Singh_2423376.ipynb
# [12/51] Grading: Kanishka Singh_2423376.ipynb
# [Local] Grading Kanishka Singh_2423376.ipynb
# [13/51] Grading: Kushagra_gulati2423347 (1).ipynb
# [Local] Grading Kushagra_gulati2423347 (1).ipynb
# [13/51] Grading: Kushagra_gulati2423347 (1).ipynb
# [Local] Grading Kushagra_gulati2423347 (1).ipynb
# [14/51] Grading: Kushagra_gulati2423347.ipynb
# [Local] Grading Kushagra_gulati2423347.ipynb
# [14/51] Grading: Kushagra_gulati2423347.ipynb
# [Local] Grading Kushagra_gulati2423347.ipynb
# [15/51] Grading: Nimrat_Singh.ipynb
# [Local] Grading Nimrat_Singh.ipynb
# [15/51] Grading: Nimrat_Singh.ipynb
# [Local] Grading Nimrat_Singh.ipynb
# [16/51] Grading: Nishant_Kumar_2423349.ipynb
# [Local] Grading Nishant_Kumar_2423349.ipynb
# [16/51] Grading: Nishant_Kumar_2423349.ipynb
# [Local] Grading Nishant_Kumar_2423349.ipynb
# [17/51] Grading: Nitin_Sahsani_2423350 (1) (1) (1) (1).ipynb
# [Local] Grading Nitin_Sahsani_2423350 (1) (1) (1) (1).ipynb
# [17/51] Grading: Nitin_Sahsani_2423350 (1) (1) (1) (1).ipynb
# [Local] Grading Nitin_Sahsani_2423350 (1) (1) (1) (1).ipynb
# [18/51] Grading: Nitin_Sahsani_2423350 (1) (1).ipynb
# [Local] Grading Nitin_Sahsani_2423350 (1) (1).ipynb
# [18/51] Grading: Nitin_Sahsani_2423350 (1) (1).ipynb
# [Local] Grading Nitin_Sahsani_2423350 (1) (1).ipynb
# [19/51] Grading: Nitin_Sahsani_2423350.ipynb
# [Local] Grading Nitin_Sahsani_2423350.ipynb
# [19/51] Grading: Nitin_Sahsani_2423350.ipynb
# [Local] Grading Nitin_Sahsani_2423350.ipynb
# [20/51] Grading: Rugved_2423370.ipynb
# [Local] Grading Rugved_2423370.ipynb
# [20/51] Grading: Rugved_2423370.ipynb
# [Local] Grading Rugved_2423370.ipynb
# [21/51] Grading: Sarthak_Chaudhary_2423346.ipynb
# [Local] Grading Sarthak_Chaudhary_2423346.ipynb
# [21/51] Grading: Sarthak_Chaudhary_2423346.ipynb
# [Local] Grading Sarthak_Chaudhary_2423346.ipynb
# [22/51] Grading: Udit_Baid_2423384.ipynb
# [Local] Grading Udit_Baid_2423384.ipynb
# [22/51] Grading: Udit_Baid_2423384.ipynb
# [Local] Grading Udit_Baid_2423384.ipynb
# [23/51] Grading: Urvi Kamble.ipynb
# [Local] Grading Urvi Kamble.ipynb
# [23/51] Grading: Urvi Kamble.ipynb
# [Local] Grading Urvi Kamble.ipynb
# [24/51] Grading: Vaishnavi Santosh Kavishetti Midsem.ipynb
# [Local] Grading Vaishnavi Santosh Kavishetti Midsem.ipynb
# [24/51] Grading: Vaishnavi Santosh Kavishetti Midsem.ipynb
# [Local] Grading Vaishnavi Santosh Kavishetti Midsem.ipynb
# [25/51] Grading: VanshRohida2423372.ipynb
# [Local] Grading VanshRohida2423372.ipynb
# [25/51] Grading: VanshRohida2423372.ipynb
# [Local] Grading VanshRohida2423372.ipynb
# D:\lab36\Downloads\jamesbond - jamesbond.csv
# [26/51] Grading: aahaan chatterjee.ipynb
# [Local] Grading aahaan chatterjee.ipynb
# [Local] Grading aahaan chatterjee.ipynb
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:2: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:2: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# [27/51] Grading: krishna2423344.ipynb
# [Local] Grading krishna2423344.ipynb
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:2: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:4: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:2: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:5: SyntaxWarning: invalid escape sequence '\l'
# [27/51] Grading: krishna2423344.ipynb
# [Local] Grading krishna2423344.ipynb
# [28/51] Grading: sample_solution.ipynb
# [Local] Grading sample_solution.ipynb
# [28/51] Grading: sample_solution.ipynb
# [Local] Grading sample_solution.ipynb
# [29/51] Grading: shaurya 2423374(1).ipynb
# [Local] Grading shaurya 2423374(1).ipynb
# [29/51] Grading: shaurya 2423374(1).ipynb
# [Local] Grading shaurya 2423374(1).ipynb
# [30/51] Grading: student_notebook (1) (1).ipynb
# [Local] Grading student_notebook (1) (1).ipynb
# [30/51] Grading: student_notebook (1) (1).ipynb
# [Local] Grading student_notebook (1) (1).ipynb
# [31/51] Grading: student_notebook (1)(1).ipynb
# [Local] Grading student_notebook (1)(1).ipynb
# [31/51] Grading: student_notebook (1)(1).ipynb
# [Local] Grading student_notebook (1)(1).ipynb
# [32/51] Grading: student_notebook (1)(2).ipynb
# [Local] Grading student_notebook (1)(2).ipynb
# [32/51] Grading: student_notebook (1)(2).ipynb
# [Local] Grading student_notebook (1)(2).ipynb
# [33/51] Grading: student_notebook (1)(3).ipynb
# [Local] Grading student_notebook (1)(3).ipynb
# [33/51] Grading: student_notebook (1)(3).ipynb
# [Local] Grading student_notebook (1)(3).ipynb
# [34/51] Grading: student_notebook (1)(4).ipynb
# [Local] Grading student_notebook (1)(4).ipynb
# [34/51] Grading: student_notebook (1)(4).ipynb
# [Local] Grading student_notebook (1)(4).ipynb
# [35/51] Grading: student_notebook (1)(5).ipynb
# [Local] Grading student_notebook (1)(5).ipynb
# [35/51] Grading: student_notebook (1)(5).ipynb
# [Local] Grading student_notebook (1)(5).ipynb
# [36/51] Grading: student_notebook (1)(6).ipynb
# [Local] Grading student_notebook (1)(6).ipynb
# [36/51] Grading: student_notebook (1)(6).ipynb
# [Local] Grading student_notebook (1)(6).ipynb
# [37/51] Grading: student_notebook (1)(7).ipynb
# [Local] Grading student_notebook (1)(7).ipynb
# [37/51] Grading: student_notebook (1)(7).ipynb
# [Local] Grading student_notebook (1)(7).ipynb
# [38/51] Grading: student_notebook (1).ipynb
# [Local] Grading student_notebook (1).ipynb
# [38/51] Grading: student_notebook (1).ipynb
# [Local] Grading student_notebook (1).ipynb
# [39/51] Grading: student_notebook (2).ipynb
# [Local] Grading student_notebook (2).ipynb
# [39/51] Grading: student_notebook (2).ipynb
# [Local] Grading student_notebook (2).ipynb
# [40/51] Grading: student_notebook 2423343.ipynb
# [Local] Grading student_notebook 2423343.ipynb
# [40/51] Grading: student_notebook 2423343.ipynb
# [Local] Grading student_notebook 2423343.ipynb
# [41/51] Grading: student_notebook 2423363(1) (1).ipynb
# [Local] Grading student_notebook 2423363(1) (1).ipynb
# [41/51] Grading: student_notebook 2423363(1) (1).ipynb
# [Local] Grading student_notebook 2423363(1) (1).ipynb
# [42/51] Grading: student_notebook 2423363(1).ipynb
# [Local] Grading student_notebook 2423363(1).ipynb
# [42/51] Grading: student_notebook 2423363(1).ipynb
# [Local] Grading student_notebook 2423363(1).ipynb
# [43/51] Grading: student_notebook(1).ipynb
# [Local] Grading student_notebook(1).ipynb
# [43/51] Grading: student_notebook(1).ipynb
# [Local] Grading student_notebook(1).ipynb
# <student_cell>:1: SyntaxWarning: invalid escape sequence '\l'
# [44/51] Grading: student_notebook(2).ipynb
# [Local] Grading student_notebook(2).ipynb
# <student_cell>:1: SyntaxWarning: invalid escape sequence '\l'
# [44/51] Grading: student_notebook(2).ipynb
# [Local] Grading student_notebook(2).ipynb
# [45/51] Grading: student_notebook(3).ipynb
# [Local] Grading student_notebook(3).ipynb
# [45/51] Grading: student_notebook(3).ipynb
# [Local] Grading student_notebook(3).ipynb
# [46/51] Grading: student_notebook(4).ipynb
# [Local] Grading student_notebook(4).ipynb
# [46/51] Grading: student_notebook(4).ipynb
# [Local] Grading student_notebook(4).ipynb
# [47/51] Grading: student_notebook(5).ipynb
# [Local] Grading student_notebook(5).ipynb
# [47/51] Grading: student_notebook(5).ipynb
# [Local] Grading student_notebook(5).ipynb
# [48/51] Grading: student_notebook.ipynb
# [Local] Grading student_notebook.ipynb
# [48/51] Grading: student_notebook.ipynb
# [Local] Grading student_notebook.ipynb
# [49/51] Grading: student_notebook_2423375.ipynb
# [Local] Grading student_notebook_2423375.ipynb
# [49/51] Grading: student_notebook_2423375.ipynb
# [Local] Grading student_notebook_2423375.ipynb
# [50/51] Grading: student_notebook_upload.ipynb
# [Local] Grading student_notebook_upload.ipynb
# [50/51] Grading: student_notebook_upload.ipynb
# [Local] Grading student_notebook_upload.ipynb
# <student_cell>:1: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:1: SyntaxWarning: invalid escape sequence '\l'
# [51/51] Grading: vikram 2423359.ipynb
# [Local] Grading vikram 2423359.ipynb
# <student_cell>:1: SyntaxWarning: invalid escape sequence '\l'
# <student_cell>:1: SyntaxWarning: invalid escape sequence '\l'
# [51/51] Grading: vikram 2423359.ipynb
# [Local] Grading vikram 2423359.ipynb
# Execution phase completed successfully.
# [Reporting] Processed 1479 result rows.
# Report generation complete.
# Total evaluation completed in 50.34s.
# Execution phase completed successfully.
# [Reporting] Processed 1479 result rows.
# Report generation complete.
# Total evaluation completed in 50.34s.
# HTML report generated at: /Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/sba_questions/reports/evaluation_report_with_tests.html
# HTML report generated at: /Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/sba_questions/reports/evaluation_report_with_tests.html
# '/Volumes/MacSSD/Areas/Github_Repositories/evaluator/data/sba_questions/reports/evaluation_report_with_tests.html'

# %%
report.executed_results
# Out:
# [{'student_path': PosixPath('Mid-Semester Exam for Batch 3/ANAY 2423357.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Anay Mittal', roll='2423357'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.73,
#    'student_meta': {'name': 'Anay Mittal', 'roll_number': '2423357'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Aakarsh_Jawa_2423380.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Aakarsh Jawa ', roll='2423380'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.55,
#    'student_meta': {'name': 'Aakarsh Jawa ', 'roll_number': '2423380'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Aradhya_Mishra_2423371.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'films_per_actor', 'filter_price_above_average', 'google_head_indexed', 'name', 'np', 'pd', 'roll_number']\n[grader] Final resolved student identity -> name='Aradhya Mishra', roll='2423371'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.58,
#    'student_meta': {'name': 'Aradhya Mishra', 'roll_number': '2423371'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/ArunMG(2423360).ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Arun Murari Gottipati', roll='2423360'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.55,
#    'student_meta': {'name': 'Arun Murari Gottipati',
#     'roll_number': '2423360'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Devansh_Grover_2423366.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Devansh Grover ', roll='2423366'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.57,
#    'student_meta': {'name': 'Devansh Grover ', 'roll_number': '2423366'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Divitvats.2423355.1.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'convert_bond_salary_to_numeric', 'convert_google_date', 'films_per_actor', 'google_head_indexed', 'name', 'np', 'pd', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Divit Vats', roll='2423355'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.56,
#    'student_meta': {'name': 'Divit Vats', 'roll_number': '2423355'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Divitvats.2423355.2.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'convert_bond_salary_to_numeric', 'convert_google_date', 'films_per_actor', 'name', 'np', 'pd', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Divit Vats', roll='2423355'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.59,
#    'student_meta': {'name': 'Divit Vats', 'roll_number': '2423355'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Divitvats.2423355.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'convert_bond_salary_to_numeric', 'convert_google_date', 'films_per_actor', 'google_head_indexed', 'name', 'np', 'pd', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Divit Vats', roll='s2423355'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.61,
#    'student_meta': {'name': 'Divit Vats', 'roll_number': 's2423355'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Johann_Karl 2423382 (2) (1).ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'np', 'pd', 'rename_bond_salary']\n[grader] Missing name/roll in namespace, scanning code cells...\n[grader] Final resolved student identity -> name='Student Name', roll='Roll Number'\n[grader] ❌ Fatal: student identity still matches instructor defaults. Skipping assertions.",
#    'docker_stderr': '',
#    'elapsed': 0.6,
#    'student_meta': {'name': 'Student Name', 'roll_number': 'Roll Number'}},
#   'results': [{'question': '_identity_check_',
#     'assertion': '[missing student identity]',
#     'status': 'failed',
#     'error': "Student notebook missing personalized name/roll_number. Please define:\n\nname = 'Your Name'\nroll_number = 'Your Roll Number'\n",
#     'score': 0,
#     'description': 'Student did not customize name/roll_number.'}]},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Johann_Karl 2423382 mid sem.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number']\n[grader] Final resolved student identity -> name='Johann Karl', roll='2423382'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.65,
#    'student_meta': {'name': 'Johann Karl', 'roll_number': '2423382'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Johann_Karl 2423382.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number']\n[grader] Final resolved student identity -> name='Sarthak Chaudhary', roll='2423346'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.54,
#    'student_meta': {'name': 'Sarthak Chaudhary', 'roll_number': '2423346'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Kanishka Singh_2423376.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'name', 'np', 'pd', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Kanishka Singh', roll='2423376'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.54,
#    'student_meta': {'name': 'Kanishka Singh', 'roll_number': '2423376'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Kushagra_gulati2423347 (1).ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Kushagra Gulati', roll='2423347'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.59,
#    'student_meta': {'name': 'Kushagra Gulati', 'roll_number': '2423347'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Kushagra_gulati2423347.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Kushagra Gulati', roll='2423347'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.53,
#    'student_meta': {'name': 'Kushagra Gulati', 'roll_number': '2423347'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Nimrat_Singh.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Nimrat Singh', roll='2423361'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.55,
#    'student_meta': {'name': 'Nimrat Singh', 'roll_number': '2423361'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Nishant_Kumar_2423349.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'films_per_actor', 'google', 'google_head_indexed', 'map_dict', 'name', 'np', 'pd', 'roll_number']\n[grader] Final resolved student identity -> name='Nishant Kumar', roll='2423349'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.6,
#    'student_meta': {'name': 'Nishant Kumar', 'roll_number': '2423349'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Nitin_Sahsani_2423350 (1) (1) (1) (1).ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Nitin Sahsani', roll='2423350'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.55,
#    'student_meta': {'name': 'Nitin Sahsani', 'roll_number': '2423350'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Nitin_Sahsani_2423350 (1) (1).ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Nitin Sahsani', roll='2423350'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.56,
#    'student_meta': {'name': 'Nitin Sahsani', 'roll_number': '2423350'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Nitin_Sahsani_2423350.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Nitin Sahsani', roll='2423350'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.55,
#    'student_meta': {'name': 'Nitin Sahsani', 'roll_number': '2423350'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Rugved_2423370.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'films_per_actor', 'filter_price_above_average', 'google_head_indexed', 'name', 'np', 'pd', 'roll_number']\n[grader] Final resolved student identity -> name='Rugved Deshpande', roll='2423370'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.68,
#    'student_meta': {'name': 'Rugved Deshpande', 'roll_number': '2423370'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Sarthak_Chaudhary_2423346.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number']\n[grader] Final resolved student identity -> name='Sarthak Chaudhary', roll='2423346'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.58,
#    'student_meta': {'name': 'Sarthak Chaudhary', 'roll_number': '2423346'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/Udit_Baid_2423384.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
# ...
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Sai Shobhith', roll='2423351'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.64,
#    'student_meta': {'name': 'Sai Shobhith', 'roll_number': '2423351'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/student_notebook(4).ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Sai Shobhith', roll='2423351'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.57,
#    'student_meta': {'name': 'Sai Shobhith', 'roll_number': '2423351'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/student_notebook(5).ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Sai Shobhith', roll='2423351'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.56,
#    'student_meta': {'name': 'Sai Shobhith', 'roll_number': '2423351'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/student_notebook.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Lalit Mohan Kumar', roll='2423375'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.61,
#    'student_meta': {'name': 'Lalit Mohan Kumar', 'roll_number': '2423375'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/student_notebook_2423375.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Lalit Mohan Kumar', roll='2423375'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.55,
#    'student_meta': {'name': 'Lalit Mohan Kumar', 'roll_number': '2423375'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/student_notebook_upload.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_columns', 'bond_head', 'bond_shape', 'convert_bond_salary_to_numeric', 'convert_google_date', 'fill_bond_salary_zero', 'films_per_actor', 'filter_price_above_average', 'google_columns', 'google_head', 'google_head_indexed', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'rename_bond_salary', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='Aniruddhan R M', roll='2423353'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.62,
#    'student_meta': {'name': 'Aniruddhan R M', 'roll_number': '2423353'}},
#   'results': []},
#  {'student_path': PosixPath('Mid-Semester Exam for Batch 3/vikram 2423359.ipynb'),
#   'execution': {'success': True,
#    'errors': [],
#    'docker_stdout': "[grader] Starting grading...\n[grader] Instructor defaults -> name='Student Name', roll='Roll Number'\n[grader] Namespace after execution: ['StringIO', 'bond_head', 'bond_shape', 'fill_bond_salary_zero', 'films_per_actor', 'google_columns', 'google_head', 'google_shape', 'load_bond', 'load_google', 'name', 'np', 'pd', 'roll_number', 'set_google_index_date']\n[grader] Final resolved student identity -> name='vikram sinha ', roll='2423359'\n[grader] Evaluating question: load_bond\n[grader] Question load_bond: 0 assertions — passed=0, failed=0\n[grader] Question load_bond: sample scores: []\n[grader] Evaluating question: bond_head\n[grader] Question bond_head: 0 assertions — passed=0, failed=0\n[grader] Question bond_head: sample scores: []\n[grader] Evaluating question: bond_columns\n[grader] Question bond_columns: 0 assertions — passed=0, failed=0\n[grader] Question bond_columns: sample scores: []\n[grader] Evaluating question: bond_shape\n[grader] Question bond_shape: 0 assertions — passed=0, failed=0\n[grader] Question bond_shape: sample scores: []\n[grader] Evaluating question: rename_bond_salary\n[grader] Question rename_bond_salary: 0 assertions — passed=0, failed=0\n[grader] Question rename_bond_salary: sample scores: []\n[grader] Evaluating question: fill_bond_salary_zero\n[grader] Question fill_bond_salary_zero: 0 assertions — passed=0, failed=0\n[grader] Question fill_bond_salary_zero: sample scores: []\n[grader] Evaluating question: set_google_index_date\n[grader] Question set_google_index_date: 0 assertions — passed=0, failed=0\n[grader] Question set_google_index_date: sample scores: []\n[grader] Evaluating question: filter_price_above_average\n[grader] Question filter_price_above_average: 0 assertions — passed=0, failed=0\n[grader] Question filter_price_above_average: sample scores: []\n[grader] results.json written with 0 rows.",
#    'docker_stderr': '',
#    'elapsed': 0.6,
#    'student_meta': {'name': 'vikram sinha ', 'roll_number': '2423359'}},
#   'results': []}]

# %% [markdown]
# # EOF
