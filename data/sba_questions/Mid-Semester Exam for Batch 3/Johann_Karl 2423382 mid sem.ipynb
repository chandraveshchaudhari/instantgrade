# %% [markdown]
# # Mid-Semester Exam
#
# This mid-semester exam contains practical pandas tasks using the provided datasets (`jamesbond.csv` and `google_stock_price.csv`).
#
# Instructions for students:
# - Implement the required functions in this notebook.
# - Each question is followed by instructor solution and a small assertion test for reference and validation.
# - Do not modify the assertion cells; they are used to validate correctness during grading.
#
# Notes:
# - The top setup cell imports necessary libraries (importing libraries is not a numbered question).
# - Each numbered question below contains a single function implementing the instructor solution and a small set of assertions verifying expected behaviour.

# %%
import pandas as pd
import numpy as np
from io import StringIO

# %%
name = 'Johann Karl'
roll_number = '2423382'

# %% [markdown]
# ---
# ## QUESTIONS
# ---

# %% [markdown]
# ### 1. Loading James Bond Dataset
#
# Return: A pandas DataFrame loaded from the CSV path or file-like object.
#
# Load the file `jamesbond.csv` into a DataFrame named `bond`.

# %%
def load_bond(path_or_buffer: str='data/sba_questions/jamesbond.csv') -> pd.DataFrame:
    bond = pd.read_csv(path_or_buffer)
    return bond
load_bond('jamesbond.csv')
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %% [markdown]
# ### 2. Loading Google Stock Dataset
#
# Return: A pandas DataFrame loaded from the CSV path or file-like object.
#
# Load the file `google_stock_price.csv` into a DataFrame named `google`.

# %%
def load_google(path_or_buffer: str='data/sba_questions/google_stock_price.csv') -> pd.DataFrame:
    google = pd.read_csv(path_or_buffer)
    return google
google= load_google('google_stock_price.csv')
google
# Out:
#             Date       Price
# 0     2004-08-19    2.490664
# 1     2004-08-20    2.515820
# 2     2004-08-23    2.758411
# 3     2004-08-24    2.770615
# 4     2004-08-25    2.614201
# ...          ...         ...
# 4788  2023-08-28  132.080002
# 4789  2023-08-29  132.998001
# 4790  2023-08-30  135.570007
# 4791  2023-08-31  137.050003
# 4792  2023-09-01  138.429993
#
# [4793 rows x 2 columns]

# %% [markdown]
# ### 3. Viewing Data – James Bond Dataset
#
# Return: A DataFrame containing the first five rows of the provided `bond` DataFrame.
#
# Display the first five rows of the `bond` DataFrame.

# %%
def bond_head(df: pd.DataFrame) -> pd.DataFrame:
    return df.head()
bond_head(bond)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %% [markdown]
# ### 4. Viewing Data – Google Stock Dataset
#
# Return: A DataFrame containing the first five rows of the provided `google` DataFrame.
#
# Display the first five rows of the `google` DataFrame.

# %%
def google_head(df: pd.DataFrame) -> pd.DataFrame:
    return df.head()
google_head(google)
# Out:
#          Date     Price
# 0  2004-08-19  2.490664
# 1  2004-08-20  2.515820
# 2  2004-08-23  2.758411
# 3  2004-08-24  2.770615
# 4  2004-08-25  2.614201

# %% [markdown]
# ### 5. Column Names – James Bond Dataset
#
# Return: A list of column names for the `bond` DataFrame.
#
# Display the column names of the `bond` DataFrame.

# %%
def bond_columns(df: pd.DataFrame) -> list:
    return df.columns
bond_columns(bond)
# Out:
# Index(['Film', 'Year', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %% [markdown]
# ### 6. Column Names – Google Stock Dataset
#
# Return: A list of column names for the `google` DataFrame.
#
# Display the column names of the `google` DataFrame.

# %%
def google_columns(df: pd.DataFrame) -> list:
    return df.columns
google_columns(google)
# Out:
# Index(['Date', 'Price'], dtype='object')

# %% [markdown]
# ### 7. Dataset Shape – James Bond Dataset
#
# Return: A tuple (number of rows, number of columns) for the `bond` DataFrame.
#
# Display the number of rows and columns in the `bond` DataFrame.

# %%
def bond_shape(df: pd.DataFrame) -> tuple:
    return df.shape
bond_shape(bond)
# Out:
# (27, 7)

# %% [markdown]
# ### 8. Dataset Shape – Google Stock Dataset
#
# Return: A tuple (number of rows, number of columns) for the `google` DataFrame.
#
# Display the number of rows and columns in the `google` DataFrame.

# %%
def google_shape(df: pd.DataFrame) -> tuple:
    return df.shape
google_shape(google)
# Out:
# (4793, 2)

# %% [markdown]
# ### 9. Rename Column – James Bond Dataset
#
# Return: A DataFrame with column `Bond Actor Salary` renamed to `Bond_Salary`.
#
# Rename the column `Bond Actor Salary` to `Bond_Salary` in the `bond` DataFrame.

# %%
def rename_bond_salary(df: pd.DataFrame) -> pd.DataFrame:
    return df.rename({"Bond Actor Salary":"Bond Salary"})
rename_bond_salary(bond)
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %% [markdown]
# ### 10. Data Type Conversion – James Bond Dataset
#
# Return: A DataFrame where the `Bond_Salary` column is of numeric dtype (non-convertible values coerced to NaN).
#
# Convert the `Bond_Salary` column to numeric using `errors='coerce'`.

# %%
def convert_bond_salary_to_numeric(df: pd.DataFrame) -> pd.DataFrame:
    df["Bond Actor Salary"]= pd.to_numeric(df["Bond Actor Salary"],errors="coerce")
    return df
convert_bond_salary_to_numeric(bond)
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %% [markdown]
# ### 11. Handling Missing Values – James Bond Dataset
#
# Return: A DataFrame where missing values in `Bond_Salary` are replaced by 0.
#
# Replace all missing values in `Bond_Salary` with `0`.

# %%
def fill_bond_salary_zero(df: pd.DataFrame) -> pd.DataFrame:
    df["Bond Actor Salary"].fillna("0")
    return df
fill_bond_salary_zero(bond)
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# 18                        GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19              Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20          The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21                  Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22                    Casino Royale  2006    Daniel Craig     Martin Campbell
# 23                Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                          Skyfall  2012    Daniel Craig          Sam Mendes
# 25                          Spectre  2015    Daniel Craig          Sam Mendes
# 26                   No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 0        448.8     7.0                0.6
# 1        543.8    12.6                1.6
# 2        820.4    18.6                3.2
# 3        848.1    41.9                4.7
# 4        315.0    85.0                NaN
# 5        514.2    59.9                4.4
# 6        291.5    37.3                0.6
# 7        442.5    34.7                5.8
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# 14       373.8    53.9                7.8
# 15       275.2    54.5                9.1
# 16       313.5    68.8                5.2
# 17       250.9    56.7                7.9
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3               30.0
# 26       774.2   301.0               25.0

# %% [markdown]
# ### 12. Date Conversion – Google Stock Dataset
#
# Return: A DataFrame where `Date` has been converted to pandas datetime dtype.
#
# Convert the `Date` column in the `google` DataFrame to datetime format.

# %%
def convert_google_date(df: pd.DataFrame) -> pd.DataFrame:
    df["Date"]= pd.to_datetime(["Date"])
    return df
convert_google_date(google)
# Out:
# ---------------------------------------------------------------------------
# DateParseError                            Traceback (most recent call last)
# Cell In[47], line 4
#       2     df["Date"]= pd.to_datetime(["Date"])
#       3     return df
# ----> 4 convert_google_date(google)
#
# Cell In[47], line 2, in convert_google_date(df)
#       1 def convert_google_date(df: pd.DataFrame) -> pd.DataFrame:
# ----> 2     df["Date"]= pd.to_datetime(["Date"])
#       3     return df
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1099, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1097         result = _convert_and_box_cache(argc, cache_array)
#    1098     else:
# -> 1099         result = convert_listlike(argc, format)
#    1100 else:
#    1101     result = convert_listlike(np.array([arg]), format)[0]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     432 if format is not None and format != "mixed":
#     433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
# --> 435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#     438     yearfirst=yearfirst,
#     439     utc=utc,
#     440     errors=errors,
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#     447     out_unit = np.datetime_data(result.dtype)[0]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2398, in objects_to_datetime64(data, dayfirst, yearfirst, utc, errors, allow_object, out_unit)
#    2395 # if str-dtype, convert
#    2396 data = np.asarray(data, dtype=np.object_)
# -> 2398 result, tz_parsed = tslib.array_to_datetime(
#    2399     data,
#    2400     errors=errors,
#    2401     utc=utc,
#    2402     dayfirst=dayfirst,
#    2403     yearfirst=yearfirst,
#    2404     creso=abbrev_to_npy_unit(out_unit),
#    2405 )
#    2407 if tz_parsed is not None:
#    2408     # We can take a shortcut since the datetime64 numpy array
#    2409     #  is in UTC
#    2410     return result, tz_parsed
#
# File tslib.pyx:414, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:596, in pandas._libs.tslib.array_to_datetime()
#
# File tslib.pyx:553, in pandas._libs.tslib.array_to_datetime()
#
# File conversion.pyx:641, in pandas._libs.tslibs.conversion.convert_str_to_tsobject()
#
# File parsing.pyx:336, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File parsing.pyx:666, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# DateParseError: Unknown datetime string format, unable to parse: Date, at position 0

# %% [markdown]
# ### 13. Setting Index – Google Stock Dataset
#
# Return: A DataFrame with `Date` set as the index.
#
# Set the `Date` column as the index of the `google` DataFrame.

# %%
def set_google_index_date(df: pd.DataFrame) -> pd.DataFrame:

# %% [markdown]
# ### 14. Display After Indexing – Google Stock Dataset
#
# Return: The first five rows of the `google` DataFrame after setting index.
#
# Display the first five rows of the `google` DataFrame after setting the index.

# %%
def google_head_indexed(df: pd.DataFrame) -> pd.DataFrame:
    pass

# %% [markdown]
# ### 15. Filtering Data – Google Stock Dataset
#
# Return: DataFrame containing rows where `Price` is greater than the average `Price`.
#
# Display all rows from the `google` DataFrame where the `Price` is greater than the average `Price`.

# %%
def filter_price_above_average(df: pd.DataFrame) -> pd.DataFrame:
    return df[(df['Price']>df['Price'].mean())]

filter_price_above_average(google)
# Out:
#             Date       Price
# 3067  2016-10-24   40.244999
# 3068  2016-10-25   40.834000
# 3069  2016-10-26   40.317001
# 3071  2016-10-28   40.417500
# 3119  2017-01-09   40.320000
# ...          ...         ...
# 4788  2023-08-28  132.080002
# 4789  2023-08-29  132.998001
# 4790  2023-08-30  135.570007
# 4791  2023-08-31  137.050003
# 4792  2023-09-01  138.429993
#
# [1672 rows x 2 columns]

# %% [markdown]
# ### 16. Grouping Data – James Bond Dataset
#
# Return: A Series mapping each actor to the number of films they performed in the dataset.
#
# Display the number of films performed by each actor using the `bond` DataFrame.

# %%
def films_per_actor(df: pd.DataFrame, actor_col: str='Actor') -> pd.Series:
    return df.groupby('Actor').count()
films_per_actor(bond)
# Out:
#                 Film  Year  Director  Box Office  Budget  Bond Actor Salary
# Actor
# Daniel Craig       5     5         5           5       5                  5
# David Niven        1     1         1           1       1                  0
# George Lazenby     1     1         1           1       1                  1
# Pierce Brosnan     4     4         4           4       4                  4
# Roger Moore        7     7         7           7       7                  2
# Sean Connery       7     7         7           7       7                  6
# Timothy Dalton     2     2         2           2       2                  2
