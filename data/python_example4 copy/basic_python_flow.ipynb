# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./data/python_example1/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent.parent     # go up two levels to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from evaluator import Evaluator

# %%
from evaluator.utils.io_utils import generate_student_notebook

generate_student_notebook(
    instructor_path="./sample_solutions.ipynb",
    output_path="./submissions/student_notebook.ipynb"
)
# Out:
# ✅ Student notebook generated at: submissions/student_notebook.ipynb

# %%
# write code to remove the jupyter notebook files in this directory "/Volumes/MacSSD/Trash/In class Practice Exam" if they have following line "from evaluator import Evaluator"
from evaluator.utils.io_utils import remove_notebook_with_line
remove_notebook_with_line(
    directory="/Volumes/MacSSD/Trash/In class Practice Exam",
    line="from evaluator import Evaluator"
)

# %%
eval = Evaluator("./sample_solutions.ipynb", "/Volumes/MacSSD/Trash/In class Practice Exam")
result = eval.run()
# Out:
# 110
# No. times  was in  is 1
# [2, 4, 6, 8, 10]
# 2.0
# 5 is positive
# -2 is negative
# 0 is zero
# No. times a was in banana is 3
# No. times p was in apple is 2
# 5 is Positive
# -2 is Negative
# 0 is Zero
# [2, 4, 6, 8, 10]
# 7.333333333333333
# 229
# 229
# 1
# is Positive
# is Negative
# is zero
# 15
# 55
# 5 is Positive
# Return : 15
# The count is: 2
# Return : [2, 4, 6, 8, 10]
# Return: 7.333333333333333
# 5 is Positive
# -2 is Negative
# 0 is Zero
# 15
# 3
# [2, 4, 6, 8, 10]
# 7.333333333333333
# 5 is Positive
# -2 is Negative
# 0 is Zero
# 5 is Positive
# -2 is Negative
# 0 is Zero
# 1
# [2, 4, 6, 8, 10]
# 229
# 210
# a has appeared 4 times in aahaan
# [2, 4, 6, 8, 10]
# 10.0
# 15
# 55
# a has appeared 3 times in banana
# p has appeared 2 times in apple
# [2, 4, 6, 8, 10]
# 7.333333333333333
# 3.0
# 210
# a has appeared 4 times in aahaan
# [2, 4, 6, 8, 10]
# 10.0
# 15
# 55
# a has appeared 3 times in banana
# p has appeared 2 times in apple
# [2, 4, 6, 8, 10]
# ...

# %%
from evaluator.utils.path_utils import filename_safe_timestamp_format

result.to_html(f"./report/report_{filename_safe_timestamp_format()}.html")
# Out:
# PosixPath('report/report_20251127_093208.html')

# %% [markdown]
# # EOF
