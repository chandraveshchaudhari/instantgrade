# %%
from pathlib import Path
from instantgrade import InstantGrader

solution = Path('./solution.ipynb')
submission = Path('./student_alice.ipynb')

grader = InstantGrader(solution_file_path=solution, submission_folder_path=submission, use_docker=False)
report = grader.run()
report.to_html('./report/student_alice_report.html')
# Out:
# Starting evaluation pipeline...
# Loading instructor solution...
# Loading instructor solution...
# Loaded 0 questions.
# Discovered 1 submissions to grade.
# Starting Local evaluation pipeline...
# [1/1] Grading: student_alice.ipynb
# [Local] Grading student_alice.ipynb
# Loaded 0 questions.
# Discovered 1 submissions to grade.
# Starting Local evaluation pipeline...
# [1/1] Grading: student_alice.ipynb
# [Local] Grading student_alice.ipynb
# Execution phase completed successfully.
# [Reporting] Processed 0 result rows.
# Report generation complete.
# Total evaluation completed in 1.04s.
# Execution phase completed successfully.
# [Reporting] Processed 0 result rows.
# Report generation complete.
# Total evaluation completed in 1.04s.
# PosixPath('report/student_alice_report.html')
