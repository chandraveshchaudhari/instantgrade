# %% [markdown]
# # Basic Python Flow

# %%
import sys
from pathlib import Path

# current notebook is inside ./data/python_example1/
NOTEBOOK_DIR = Path().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent.parent     # go up two levels to project root

sys.path.append(str(PROJECT_ROOT / "src"))

from instantgrade import Evaluator

# %% [markdown]
# from instantgrade.utils.io_utils import generate_student_notebook
#
# generate_student_notebook(
#     instructor_path="./pandas_practice.ipynb",
#     output_path="./submissions/student_notebook.ipynb"
# )

# %%
from instantgrade import Evaluator

eval = Evaluator(
    solution_file_path="./fib_solution.ipynb",
    submission_folder_path="./assignment_files",
    use_docker=False,       # or False for local test mode
    log_path="./logs",
    log_level="normal",
)

report = eval.run()
eval.to_html("./reports/fib_assignment.html")
# Out:
# Starting evaluation pipeline...
# Loading instructor solution...
# Loaded 10 questions.
# Discovered 293 submissions to grade.
# Starting Local evaluation pipeline...
# [1/293] Grading: Mid_SEM_Test_2423539.ipynb
# [Local] Grading Mid_SEM_Test_2423539.ipynb
# [2/293] Grading: Mid_SEM_Test_2_2423011.ipynb
# [Local] Grading Mid_SEM_Test_2_2423011.ipynb
# [3/293] Grading: Mid_SEM_Test_2_2423020.ipynb
# [Local] Grading Mid_SEM_Test_2_2423020.ipynb
# [4/293] Grading: Mid_SEM_Test_2_2423023.ipynb
# [Local] Grading Mid_SEM_Test_2_2423023.ipynb
# [5/293] Grading: Mid_SEM_Test_2_2423034.ipynb
# [Local] Grading Mid_SEM_Test_2_2423034.ipynb
# [6/293] Grading: Mid_SEM_Test_2_2423059 mid sem (1).ipynb
# [Local] Grading Mid_SEM_Test_2_2423059 mid sem (1).ipynb
# [7/293] Grading: Mid_SEM_Test_2_Aaryak Garg 2423003.ipynb
# [Local] Grading Mid_SEM_Test_2_Aaryak Garg 2423003.ipynb
# [8/293] Grading: Mid_SEM_Test_2_Bismanjyot Singh Sethi 2423010 Mid Sem (11).ipynb
# ...

# %%
from instantgrade import Evaluator


eval = Evaluator(
    solution_file_path="./fne_solution.ipynb",
    submission_folder_path="./assignment_files",
    use_docker=False,       # or False for local test mode
    log_path="./logs",
    log_level="normal",
)

report = eval.run()
eval.to_html("./reports/fne_assignment.html")
# Out:
# Starting evaluation pipeline...
# Loading instructor solution...
# Loaded 10 questions.
# Discovered 293 submissions to grade.
# Starting Local evaluation pipeline...
# [1/293] Grading: Mid_SEM_Test_2423539.ipynb
# [Local] Grading Mid_SEM_Test_2423539.ipynb
# [2/293] Grading: Mid_SEM_Test_2_2423011.ipynb
# [Local] Grading Mid_SEM_Test_2_2423011.ipynb
# Hot
# Hot
# Warm
# Warm
# Warm
# Warm
# Warm
# Warm
# Cold
# Cold
# Hot
# Hot
# [3/293] Grading: Mid_SEM_Test_2_2423020.ipynb
# [Local] Grading Mid_SEM_Test_2_2423020.ipynb
# [4/293] Grading: Mid_SEM_Test_2_2423023.ipynb
# [Local] Grading Mid_SEM_Test_2_2423023.ipynb
# [5/293] Grading: Mid_SEM_Test_2_2423034.ipynb
# [Local] Grading Mid_SEM_Test_2_2423034.ipynb
# [6/293] Grading: Mid_SEM_Test_2_2423059 mid sem (1).ipynb
# [Local] Grading Mid_SEM_Test_2_2423059 mid sem (1).ipynb
# [7/293] Grading: Mid_SEM_Test_2_Aaryak Garg 2423003.ipynb
# [Local] Grading Mid_SEM_Test_2_Aaryak Garg 2423003.ipynb
# ...

# %% [markdown]
# # EOF
